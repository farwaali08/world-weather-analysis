# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Import other dependencies:

# Import the requests library.
import requests

# Import the API key.
from config2 import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | saint-paul
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | fare
# Processing Record 6 of Set 1 | port augusta
# Processing Record 7 of Set 1 | salalah
# Processing Record 8 of Set 1 | juneau
# Processing Record 9 of Set 1 | nanortalik
# Processing Record 10 of Set 1 | thompson
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | marawi
# Processing Record 13 of Set 1 | pimentel
# Processing Record 14 of Set 1 | porto novo
# Processing Record 15 of Set 1 | victoria
# Processing Record 16 of Set 1 | babanusah
# City not found. Skipping...
# Processing Record 17 of Set 1 | silver city
# Processing Record 18 of Set 1 | mahebourg
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | korsakov
# Processing Record 21 of Set 1 | surt
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | asau
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | vilhena
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | kaitangata
# Processing Record 29 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | piacabucu
# Processing Record 33 of Set 1 | upernavik
# Processing Record 34 of Set 1 | shintomi
# Processing Record 35 of Set 1 | cesis
# Processing Record 36 of Set 1 | wonthaggi
# Processing Record 37 of Set 1 | butaritari
# Processing Record 38 of Set 1 | meiningen
# Processing Record 39 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | ewa beach
# Processing Record 42 of Set 1 | mahanoro
# Processing Record 43 of Set 1 | whitehorse
# Processing Record 44 of Set 1 | faanui
# Processing Record 45 of Set 1 | fukue
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 1 | birao
# Processing Record 49 of Set 1 | dawei
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | tirumullaivasal
# Processing Record 2 of Set 2 | omaruru
# Processing Record 3 of Set 2 | tuatapere
# Processing Record 4 of Set 2 | dali
# Processing Record 5 of Set 2 | sao filipe
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | sobolevo
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | port elizabeth
# Processing Record 11 of Set 2 | jamestown
# Processing Record 12 of Set 2 | ambovombe
# Processing Record 13 of Set 2 | new norfolk
# Processing Record 14 of Set 2 | georgetown
# Processing Record 15 of Set 2 | mezen
# Processing Record 16 of Set 2 | airai
# Processing Record 17 of Set 2 | tasiilaq
# Processing Record 18 of Set 2 | talnakh
# Processing Record 19 of Set 2 | port lincoln
# Processing Record 20 of Set 2 | yanchukan
# City not found. Skipping...
# Processing Record 21 of Set 2 | akcaabat
# Processing Record 22 of Set 2 | beringovskiy
# Processing Record 23 of Set 2 | atuona
# Processing Record 24 of Set 2 | wahiawa
# Processing Record 25 of Set 2 | merauke
# Processing Record 26 of Set 2 | ponta do sol
# Processing Record 27 of Set 2 | saint-philippe
# Processing Record 28 of Set 2 | pandamatenga
# Processing Record 29 of Set 2 | hualmay
# Processing Record 30 of Set 2 | nikolskoye
# Processing Record 31 of Set 2 | pevek
# Processing Record 32 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 2 | saskylakh
# Processing Record 34 of Set 2 | bredasdorp
# Processing Record 35 of Set 2 | laerdalsoyri
# Processing Record 36 of Set 2 | kapaa
# Processing Record 37 of Set 2 | petrolandia
# City not found. Skipping...
# Processing Record 38 of Set 2 | san pedro
# Processing Record 39 of Set 2 | san jeronimo
# Processing Record 40 of Set 2 | terrasini
# Processing Record 41 of Set 2 | dingle
# Processing Record 42 of Set 2 | yatsushiro
# Processing Record 43 of Set 2 | faya
# Processing Record 44 of Set 2 | vung tau
# Processing Record 45 of Set 2 | pangnirtung
# Processing Record 46 of Set 2 | ponta delgada
# Processing Record 47 of Set 2 | saint-francois
# Processing Record 48 of Set 2 | tiksi
# Processing Record 49 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 2 | tucuman
# Processing Record 1 of Set 3 | ostrovnoy
# Processing Record 2 of Set 3 | watsa
# Processing Record 3 of Set 3 | kupino
# Processing Record 4 of Set 3 | belyy yar
# Processing Record 5 of Set 3 | magomeni
# Processing Record 6 of Set 3 | khatanga
# Processing Record 7 of Set 3 | kavaratti
# Processing Record 8 of Set 3 | chicama
# Processing Record 9 of Set 3 | krasnogorskoye
# Processing Record 10 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 3 | sorland
# Processing Record 12 of Set 3 | lompoc
# Processing Record 13 of Set 3 | omboue
# Processing Record 14 of Set 3 | puerto ayora
# Processing Record 15 of Set 3 | luderitz
# Processing Record 16 of Set 3 | lata
# Processing Record 17 of Set 3 | ijaki
# City not found. Skipping...
# Processing Record 18 of Set 3 | minas
# Processing Record 19 of Set 3 | phan thiet
# Processing Record 20 of Set 3 | makakilo city
# Processing Record 21 of Set 3 | muana
# Processing Record 22 of Set 3 | alyangula
# Processing Record 23 of Set 3 | wanning
# Processing Record 24 of Set 3 | karla
# Processing Record 25 of Set 3 | pareora
# Processing Record 26 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 3 | anadyr
# Processing Record 28 of Set 3 | adrar
# Processing Record 29 of Set 3 | severo-kurilsk
# Processing Record 30 of Set 3 | cap malheureux
# Processing Record 31 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 3 | puerto escondido
# Processing Record 33 of Set 3 | angoche
# Processing Record 34 of Set 3 | port alfred
# Processing Record 35 of Set 3 | buraydah
# Processing Record 36 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 3 | chamlykskaya
# Processing Record 38 of Set 3 | saint-georges
# Processing Record 39 of Set 3 | hofn
# Processing Record 40 of Set 3 | avera
# Processing Record 41 of Set 3 | camacha
# Processing Record 42 of Set 3 | constitucion
# Processing Record 43 of Set 3 | narsaq
# Processing Record 44 of Set 3 | sept-iles
# Processing Record 45 of Set 3 | chapais
# Processing Record 46 of Set 3 | filadelfia
# Processing Record 47 of Set 3 | cherskiy
# Processing Record 48 of Set 3 | kendari
# Processing Record 49 of Set 3 | komsomolskiy
# Processing Record 50 of Set 3 | murray bridge
# Processing Record 1 of Set 4 | mugur-aksy
# Processing Record 2 of Set 4 | la ronge
# Processing Record 3 of Set 4 | louis trichardt
# Processing Record 4 of Set 4 | fortuna
# Processing Record 5 of Set 4 | dargaville
# Processing Record 6 of Set 4 | coari
# Processing Record 7 of Set 4 | buchanan
# Processing Record 8 of Set 4 | kirkwall
# Processing Record 9 of Set 4 | taksimo
# Processing Record 10 of Set 4 | lavras da mangabeira
# Processing Record 11 of Set 4 | umm lajj
# Processing Record 12 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 13 of Set 4 | punta arenas
# Processing Record 14 of Set 4 | nome
# Processing Record 15 of Set 4 | hasaki
# Processing Record 16 of Set 4 | bethel
# Processing Record 17 of Set 4 | rabaul
# Processing Record 18 of Set 4 | bengkulu
# Processing Record 19 of Set 4 | inhambane
# Processing Record 20 of Set 4 | kathmandu
# Processing Record 21 of Set 4 | sistranda
# Processing Record 22 of Set 4 | norman wells
# Processing Record 23 of Set 4 | andenes
# Processing Record 24 of Set 4 | henties bay
# Processing Record 25 of Set 4 | san cristobal
# Processing Record 26 of Set 4 | beyneu
# Processing Record 27 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 28 of Set 4 | lebu
# Processing Record 29 of Set 4 | hithadhoo
# Processing Record 30 of Set 4 | provideniya
# Processing Record 31 of Set 4 | ancud
# Processing Record 32 of Set 4 | mar del plata
# Processing Record 33 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 4 | richards bay
# Processing Record 35 of Set 4 | oistins
# Processing Record 36 of Set 4 | manta
# Processing Record 37 of Set 4 | avarua
# Processing Record 38 of Set 4 | vieste
# Processing Record 39 of Set 4 | amahai
# Processing Record 40 of Set 4 | tanabe
# Processing Record 41 of Set 4 | tilichiki
# Processing Record 42 of Set 4 | poum
# Processing Record 43 of Set 4 | swinford
# Processing Record 44 of Set 4 | moshupa
# Processing Record 45 of Set 4 | cape town
# Processing Record 46 of Set 4 | montreux
# Processing Record 47 of Set 4 | sakaraha
# Processing Record 48 of Set 4 | kanungu
# Processing Record 49 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 4 | kinsale
# Processing Record 1 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 5 | mildura
# Processing Record 3 of Set 5 | oranjemund
# Processing Record 4 of Set 5 | flinders
# Processing Record 5 of Set 5 | wenzhou
# Processing Record 6 of Set 5 | chabahar
# Processing Record 7 of Set 5 | ilulissat
# Processing Record 8 of Set 5 | tuktoyaktuk
# Processing Record 9 of Set 5 | kothapet
# Processing Record 10 of Set 5 | shimoda
# Processing Record 11 of Set 5 | svetlogorsk
# Processing Record 12 of Set 5 | bathsheba
# Processing Record 13 of Set 5 | rocha
# Processing Record 14 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 5 | castro
# Processing Record 16 of Set 5 | wexford
# Processing Record 17 of Set 5 | pangai
# Processing Record 18 of Set 5 | bariadi
# Processing Record 19 of Set 5 | hagere selam
# Processing Record 20 of Set 5 | palmeira
# Processing Record 21 of Set 5 | viseu
# Processing Record 22 of Set 5 | aksarka
# Processing Record 23 of Set 5 | san patricio
# Processing Record 24 of Set 5 | pisco
# Processing Record 25 of Set 5 | yulara
# Processing Record 26 of Set 5 | carnarvon
# Processing Record 27 of Set 5 | suzu
# City not found. Skipping...
# Processing Record 28 of Set 5 | korla
# Processing Record 29 of Set 5 | codrington
# Processing Record 30 of Set 5 | rawson
# Processing Record 31 of Set 5 | vila
# Processing Record 32 of Set 5 | northam
# Processing Record 33 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 5 | port macquarie
# Processing Record 35 of Set 5 | kozova
# Processing Record 36 of Set 5 | chengde
# Processing Record 37 of Set 5 | kodiak
# Processing Record 38 of Set 5 | turukhansk
# Processing Record 39 of Set 5 | mayumba
# Processing Record 40 of Set 5 | ahumada
# City not found. Skipping...
# Processing Record 41 of Set 5 | rio grande
# Processing Record 42 of Set 5 | palana
# Processing Record 43 of Set 5 | cabo san lucas
# Processing Record 44 of Set 5 | coyotepec
# Processing Record 45 of Set 5 | klaksvik
# Processing Record 46 of Set 5 | smithers
# Processing Record 47 of Set 5 | cayenne
# Processing Record 48 of Set 5 | cockburn town
# Processing Record 49 of Set 5 | krasnoselkup
# Processing Record 50 of Set 5 | katsuura
# Processing Record 1 of Set 6 | paamiut
# Processing Record 2 of Set 6 | talcahuano
# Processing Record 3 of Set 6 | tygda
# Processing Record 4 of Set 6 | baruun-urt
# Processing Record 5 of Set 6 | yarim
# Processing Record 6 of Set 6 | taltal
# Processing Record 7 of Set 6 | champasak
# Processing Record 8 of Set 6 | guerrero negro
# Processing Record 9 of Set 6 | amga
# Processing Record 10 of Set 6 | homer
# Processing Record 11 of Set 6 | miyang
# Processing Record 12 of Set 6 | sinnamary
# Processing Record 13 of Set 6 | toucheng
# Processing Record 14 of Set 6 | sayyan
# Processing Record 15 of Set 6 | burgersdorp
# Processing Record 16 of Set 6 | caravelas
# Processing Record 17 of Set 6 | skibbereen
# Processing Record 18 of Set 6 | aksu
# Processing Record 19 of Set 6 | havre-saint-pierre
# Processing Record 20 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 6 | seoul
# Processing Record 22 of Set 6 | tigil
# Processing Record 23 of Set 6 | fez
# Processing Record 24 of Set 6 | birin
# Processing Record 25 of Set 6 | ereymentau
# Processing Record 26 of Set 6 | rio gallegos
# Processing Record 27 of Set 6 | cape girardeau
# Processing Record 28 of Set 6 | mount gambier
# Processing Record 29 of Set 6 | camabatela
# Processing Record 30 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 31 of Set 6 | tazovskiy
# Processing Record 32 of Set 6 | bambous virieux
# Processing Record 33 of Set 6 | sitka
# Processing Record 34 of Set 6 | wattegama
# Processing Record 35 of Set 6 | aklavik
# Processing Record 36 of Set 6 | longyearbyen
# Processing Record 37 of Set 6 | omachi
# Processing Record 38 of Set 6 | sinazongwe
# Processing Record 39 of Set 6 | souillac
# Processing Record 40 of Set 6 | puerto colombia
# Processing Record 41 of Set 6 | bemidji
# Processing Record 42 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 6 | emerald
# Processing Record 44 of Set 6 | yamada
# Processing Record 45 of Set 6 | mucurapo
# Processing Record 46 of Set 6 | villafranca de los barros
# Processing Record 47 of Set 6 | kutum
# Processing Record 48 of Set 6 | la ligua
# Processing Record 49 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 6 | bedford
# Processing Record 1 of Set 7 | raudeberg
# Processing Record 2 of Set 7 | wajima
# Processing Record 3 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 4 of Set 7 | chokurdakh
# Processing Record 5 of Set 7 | kiunga
# Processing Record 6 of Set 7 | calca
# Processing Record 7 of Set 7 | kashan
# Processing Record 8 of Set 7 | grindavik
# Processing Record 9 of Set 7 | tual
# Processing Record 10 of Set 7 | naze
# Processing Record 11 of Set 7 | college
# Processing Record 12 of Set 7 | coolum beach
# Processing Record 13 of Set 7 | kumasi
# Processing Record 14 of Set 7 | acapulco
# Processing Record 15 of Set 7 | padang
# Processing Record 16 of Set 7 | kandry
# Processing Record 17 of Set 7 | vao
# Processing Record 18 of Set 7 | puerto leguizamo
# Processing Record 19 of Set 7 | chuy
# Processing Record 20 of Set 7 | port blair
# Processing Record 21 of Set 7 | bangui
# Processing Record 22 of Set 7 | arrifes
# Processing Record 23 of Set 7 | vogar
# Processing Record 24 of Set 7 | roura
# Processing Record 25 of Set 7 | leningradskiy
# Processing Record 26 of Set 7 | tottori
# Processing Record 27 of Set 7 | placido de castro
# Processing Record 28 of Set 7 | jaca
# Processing Record 29 of Set 7 | gabriel leyva solano
# Processing Record 30 of Set 7 | dingli
# Processing Record 31 of Set 7 | masumbwe
# Processing Record 32 of Set 7 | marv dasht
# City not found. Skipping...
# Processing Record 33 of Set 7 | lucapa
# Processing Record 34 of Set 7 | bereda
# Processing Record 35 of Set 7 | yanacancha
# Processing Record 36 of Set 7 | kruisfontein
# Processing Record 37 of Set 7 | namibe
# Processing Record 38 of Set 7 | bababe
# City not found. Skipping...
# Processing Record 39 of Set 7 | banda aceh
# Processing Record 40 of Set 7 | walvis bay
# Processing Record 41 of Set 7 | sobrance
# Processing Record 42 of Set 7 | lucea
# Processing Record 43 of Set 7 | biloela
# Processing Record 44 of Set 7 | sibolga
# Processing Record 45 of Set 7 | labuhan
# Processing Record 46 of Set 7 | margate
# Processing Record 47 of Set 7 | vila velha
# Processing Record 48 of Set 7 | harboore
# Processing Record 49 of Set 7 | deputatskiy
# Processing Record 50 of Set 7 | kamarion
# Processing Record 1 of Set 8 | honningsvag
# Processing Record 2 of Set 8 | yuanping
# Processing Record 3 of Set 8 | shakawe
# Processing Record 4 of Set 8 | iqaluit
# Processing Record 5 of Set 8 | christchurch
# Processing Record 6 of Set 8 | dikson
# Processing Record 7 of Set 8 | kimbe
# Processing Record 8 of Set 8 | kerman
# Processing Record 9 of Set 8 | arlit
# Processing Record 10 of Set 8 | akyab
# Processing Record 11 of Set 8 | staraya mayna
# Processing Record 12 of Set 8 | mayor pablo lagerenza
# Processing Record 13 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 14 of Set 8 | antofagasta
# Processing Record 15 of Set 8 | rupert
# Processing Record 16 of Set 8 | buenaventura
# Processing Record 17 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 18 of Set 8 | domoni
# Processing Record 19 of Set 8 | bend
# Processing Record 20 of Set 8 | iisalmi
# Processing Record 21 of Set 8 | oksfjord
# Processing Record 22 of Set 8 | cazaje
# City not found. Skipping...
# Processing Record 23 of Set 8 | opunake
# Processing Record 24 of Set 8 | ongandjera
# Processing Record 25 of Set 8 | nouakchott
# Processing Record 26 of Set 8 | saldanha
# Processing Record 27 of Set 8 | izumo
# Processing Record 28 of Set 8 | meulaboh
# Processing Record 29 of Set 8 | rohru
# Processing Record 30 of Set 8 | kantang
# Processing Record 31 of Set 8 | cabedelo
# Processing Record 32 of Set 8 | bagnan
# Processing Record 33 of Set 8 | tezu
# Processing Record 34 of Set 8 | sioux lookout
# Processing Record 35 of Set 8 | bayonet point
# Processing Record 36 of Set 8 | tocopilla
# Processing Record 37 of Set 8 | poronaysk
# Processing Record 38 of Set 8 | abaza
# Processing Record 39 of Set 8 | mana
# Processing Record 40 of Set 8 | karlshamn
# Processing Record 41 of Set 8 | montero
# Processing Record 42 of Set 8 | hukuntsi
# Processing Record 43 of Set 8 | rosetown
# Processing Record 44 of Set 8 | hilo
# Processing Record 45 of Set 8 | tuy hoa
# Processing Record 46 of Set 8 | palmer
# Processing Record 47 of Set 8 | sibu
# Processing Record 48 of Set 8 | granja
# Processing Record 49 of Set 8 | nemuro
# Processing Record 50 of Set 8 | saint-pierre
# Processing Record 1 of Set 9 | stuttgart
# Processing Record 2 of Set 9 | ulladulla
# Processing Record 3 of Set 9 | burica
# City not found. Skipping...
# Processing Record 4 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 9 | olafsvik
# Processing Record 6 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 8 of Set 9 | grong
# Processing Record 9 of Set 9 | san lazaro
# Processing Record 10 of Set 9 | suez
# Processing Record 11 of Set 9 | vila do maio
# Processing Record 12 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 9 | birjand
# Processing Record 14 of Set 9 | torbay
# Processing Record 15 of Set 9 | severobaykalsk
# Processing Record 16 of Set 9 | yinchuan
# Processing Record 17 of Set 9 | lewistown
# Processing Record 18 of Set 9 | tres lagoas
# Processing Record 19 of Set 9 | muros
# Processing Record 20 of Set 9 | birganj
# Processing Record 21 of Set 9 | storforshei
# Processing Record 22 of Set 9 | sao joao da barra
# Processing Record 23 of Set 9 | matagami
# Processing Record 24 of Set 9 | sorong
# Processing Record 25 of Set 9 | ust-kut
# Processing Record 26 of Set 9 | sironj
# Processing Record 27 of Set 9 | zhanaozen
# Processing Record 28 of Set 9 | paciran
# Processing Record 29 of Set 9 | pemba
# Processing Record 30 of Set 9 | zhoucheng
# Processing Record 31 of Set 9 | caucaia
# Processing Record 32 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 9 | thinadhoo
# Processing Record 34 of Set 9 | kuito
# Processing Record 35 of Set 9 | okhotsk
# Processing Record 36 of Set 9 | tevriz
# Processing Record 37 of Set 9 | evensk
# Processing Record 38 of Set 9 | a coruna
# Processing Record 39 of Set 9 | kieta
# Processing Record 40 of Set 9 | semirom
# Processing Record 41 of Set 9 | husavik
# Processing Record 42 of Set 9 | seydisehir
# Processing Record 43 of Set 9 | dvinskoy
# Processing Record 44 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 9 | ciudad bolivar
# Processing Record 46 of Set 9 | bandarbeyla
# Processing Record 47 of Set 9 | kawalu
# Processing Record 48 of Set 9 | kalmunai
# Processing Record 49 of Set 9 | the valley
# Processing Record 50 of Set 9 | tepetzintla
# Processing Record 1 of Set 10 | kahului
# Processing Record 2 of Set 10 | srandakan
# Processing Record 3 of Set 10 | rio verde de mato grosso
# Processing Record 4 of Set 10 | omsukchan
# Processing Record 5 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 10 | we
# City not found. Skipping...
# Processing Record 7 of Set 10 | tupik
# Processing Record 8 of Set 10 | broome
# Processing Record 9 of Set 10 | kontagora
# Processing Record 10 of Set 10 | alghero
# Processing Record 11 of Set 10 | bourail
# Processing Record 12 of Set 10 | aswan
# Processing Record 13 of Set 10 | mathathane
# Processing Record 14 of Set 10 | touros
# Processing Record 15 of Set 10 | saint anthony
# Processing Record 16 of Set 10 | kamaishi
# Processing Record 17 of Set 10 | coquimbo
# Processing Record 18 of Set 10 | west richland
# Processing Record 19 of Set 10 | maldonado
# Processing Record 20 of Set 10 | namatanai
# Processing Record 21 of Set 10 | dakar
# Processing Record 22 of Set 10 | yerbogachen
# Processing Record 23 of Set 10 | powell river
# Processing Record 24 of Set 10 | iranshahr
# Processing Record 25 of Set 10 | saint george
# Processing Record 26 of Set 10 | maracacume
# Processing Record 27 of Set 10 | yanam
# Processing Record 28 of Set 10 | vila franca do campo
# Processing Record 29 of Set 10 | itoman
# Processing Record 30 of Set 10 | guane
# Processing Record 31 of Set 10 | roma
# Processing Record 32 of Set 10 | kavieng
# Processing Record 33 of Set 10 | muli
# Processing Record 34 of Set 10 | vohibinany
# Processing Record 35 of Set 10 | bambanglipuro
# Processing Record 36 of Set 10 | ouro preto do oeste
# Processing Record 37 of Set 10 | mitsamiouli
# Processing Record 38 of Set 10 | vostok
# Processing Record 39 of Set 10 | greeley
# Processing Record 40 of Set 10 | lorengau
# Processing Record 41 of Set 10 | manchester
# Processing Record 42 of Set 10 | charters towers
# Processing Record 43 of Set 10 | lobito
# Processing Record 44 of Set 10 | esperance
# Processing Record 45 of Set 10 | boueni
# Processing Record 46 of Set 10 | kosonsoy
# Processing Record 47 of Set 10 | sangar
# Processing Record 48 of Set 10 | maniitsoq
# Processing Record 49 of Set 10 | brezno
# Processing Record 50 of Set 10 | muborak
# Processing Record 1 of Set 11 | parker
# Processing Record 2 of Set 11 | jackson
# Processing Record 3 of Set 11 | takaka
# Processing Record 4 of Set 11 | martapura
# Processing Record 5 of Set 11 | gizo
# Processing Record 6 of Set 11 | hervey bay
# Processing Record 7 of Set 11 | moyale
# Processing Record 8 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 9 of Set 11 | syamzha
# Processing Record 10 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 11 of Set 11 | riyadh
# Processing Record 12 of Set 11 | phetchaburi
# Processing Record 13 of Set 11 | bhanpuri
# Processing Record 14 of Set 11 | terryville
# Processing Record 15 of Set 11 | san luis
# Processing Record 16 of Set 11 | karpogory
# Processing Record 17 of Set 11 | lyuban
# Processing Record 18 of Set 11 | olinda
# Processing Record 19 of Set 11 | coihaique
# Processing Record 20 of Set 11 | tahoua
# Processing Record 21 of Set 11 | oeiras do para
# Processing Record 22 of Set 11 | arcachon
# Processing Record 23 of Set 11 | maceio
# Processing Record 24 of Set 11 | myitkyina
# Processing Record 25 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 11 | mount pleasant
# Processing Record 27 of Set 11 | lasa
# Processing Record 28 of Set 11 | ust-tsilma
# Processing Record 29 of Set 11 | atambua
# Processing Record 30 of Set 11 | sabancuy
# Processing Record 31 of Set 11 | summerland
# Processing Record 32 of Set 11 | laje
# Processing Record 33 of Set 11 | zhanakorgan
# Processing Record 34 of Set 11 | tura
# Processing Record 35 of Set 11 | kez
# Processing Record 36 of Set 11 | garden city
# Processing Record 37 of Set 11 | ibra
# Processing Record 38 of Set 11 | conceicao do araguaia
# Processing Record 39 of Set 11 | kununurra
# Processing Record 40 of Set 11 | voh
# Processing Record 41 of Set 11 | portland
# Processing Record 42 of Set 11 | ayan
# Processing Record 43 of Set 11 | hobyo
# Processing Record 44 of Set 11 | zyryanka
# Processing Record 45 of Set 11 | gravdal
# Processing Record 46 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 47 of Set 11 | amapa
# Processing Record 48 of Set 11 | galesong
# Processing Record 49 of Set 11 | yar-sale
# Processing Record 50 of Set 11 | byron bay
# Processing Record 1 of Set 12 | tamiahua
# Processing Record 2 of Set 12 | igarka
# Processing Record 3 of Set 12 | chenghai
# Processing Record 4 of Set 12 | abha
# Processing Record 5 of Set 12 | gasa
# Processing Record 6 of Set 12 | jamshedpur
# Processing Record 7 of Set 12 | lavrentiya
# Processing Record 8 of Set 12 | san carlos de bariloche
# Processing Record 9 of Set 12 | kotel
# Processing Record 10 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 12 | marabba
# Processing Record 12 of Set 12 | george
# Processing Record 13 of Set 12 | yazoo city
# Processing Record 14 of Set 12 | himeji
# Processing Record 15 of Set 12 | brae
# Processing Record 16 of Set 12 | dongsheng
# Processing Record 17 of Set 12 | de aar
# Processing Record 18 of Set 12 | miramar
# Processing Record 19 of Set 12 | kyaikkami
# Processing Record 20 of Set 12 | canyon
# Processing Record 21 of Set 12 | santa maria
# Processing Record 22 of Set 12 | havelock
# Processing Record 23 of Set 12 | kirakira
# Processing Record 24 of Set 12 | standish
# Processing Record 25 of Set 12 | valparaiso
# Processing Record 26 of Set 12 | pontes e lacerda
# Processing Record 27 of Set 12 | destin
# Processing Record 28 of Set 12 | zhigansk
# Processing Record 29 of Set 12 | nyurba
# Processing Record 30 of Set 12 | lagoa
# Processing Record 31 of Set 12 | honiara
# Processing Record 32 of Set 12 | gisborne
# Processing Record 33 of Set 12 | san borja
# Processing Record 34 of Set 12 | craig
# Processing Record 35 of Set 12 | nelson bay
# Processing Record 36 of Set 12 | zemio
# Processing Record 37 of Set 12 | mocuba
# Processing Record 38 of Set 12 | kushmurun
# Processing Record 39 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 40 of Set 12 | trairi
# Processing Record 41 of Set 12 | bella union
# Processing Record 42 of Set 12 | roswell
# Processing Record 43 of Set 12 | gambela
# Processing Record 44 of Set 12 | ascension
# Processing Record 45 of Set 12 | punto fijo
# Processing Record 46 of Set 12 | benghazi
# Processing Record 47 of Set 12 | aberdeen
# Processing Record 48 of Set 12 | zambezi
# Processing Record 49 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 50 of Set 12 | solin
# Processing Record 1 of Set 13 | bilibino
# Processing Record 2 of Set 13 | requena
# Processing Record 3 of Set 13 | axim
# Processing Record 4 of Set 13 | san quintin
# Processing Record 5 of Set 13 | anloga
# Processing Record 6 of Set 13 | fairbanks
# Processing Record 7 of Set 13 | dunedin
# Processing Record 8 of Set 13 | sapouy
# Processing Record 9 of Set 13 | jacareacanga
# Processing Record 10 of Set 13 | srednekolymsk
# Processing Record 11 of Set 13 | verkhnevilyuysk
# Processing Record 12 of Set 13 | lavumisa
# Processing Record 13 of Set 13 | formosa do rio preto
# Processing Record 14 of Set 13 | xining
# Processing Record 15 of Set 13 | sabang
# Processing Record 16 of Set 13 | kakching
# Processing Record 17 of Set 13 | waipawa
# Processing Record 18 of Set 13 | gogrial
# Processing Record 19 of Set 13 | morondava
# Processing Record 20 of Set 13 | bama
# Processing Record 21 of Set 13 | plettenberg bay
# Processing Record 22 of Set 13 | kysyl-syr
# Processing Record 23 of Set 13 | beloha
# Processing Record 24 of Set 13 | fort nelson
# Processing Record 25 of Set 13 | pundaguitan
# Processing Record 26 of Set 13 | tautira
# Processing Record 27 of Set 13 | te anau
# Processing Record 28 of Set 13 | novyy urengoy
# Processing Record 29 of Set 13 | kracheh
# City not found. Skipping...
# Processing Record 30 of Set 13 | ola
# Processing Record 31 of Set 13 | geraldton
# Processing Record 32 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 33 of Set 13 | kalevala
# Processing Record 34 of Set 13 | tabialan
# City not found. Skipping...
# Processing Record 35 of Set 13 | gerardmer
# Processing Record 36 of Set 13 | merke
# Processing Record 37 of Set 13 | ranong
# Processing Record 38 of Set 13 | leshukonskoye
# Processing Record 39 of Set 13 | sao gabriel
# Processing Record 40 of Set 13 | madrid
# Processing Record 41 of Set 13 | key west
# Processing Record 42 of Set 13 | karlskoga
# Processing Record 43 of Set 13 | inirida
# Processing Record 44 of Set 13 | west wendover
# Processing Record 45 of Set 13 | port hardy
# Processing Record 46 of Set 13 | fort frances
# Processing Record 47 of Set 13 | gannan
# Processing Record 48 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 49 of Set 13 | kigoma
# Processing Record 50 of Set 13 | galchino
# City not found. Skipping...
# Processing Record 1 of Set 14 | moyobamba
# Processing Record 2 of Set 14 | weligama
# Processing Record 3 of Set 14 | marsh harbour
# Processing Record 4 of Set 14 | kyren
# Processing Record 5 of Set 14 | nongan
# Processing Record 6 of Set 14 | makat
# Processing Record 7 of Set 14 | dudinka
# Processing Record 8 of Set 14 | wewak
# Processing Record 9 of Set 14 | lowestoft
# Processing Record 10 of Set 14 | alofi
# Processing Record 11 of Set 14 | senekal
# Processing Record 12 of Set 14 | kelo
# Processing Record 13 of Set 14 | half moon bay
# Processing Record 14 of Set 14 | murgab
# Processing Record 15 of Set 14 | pascagoula
# Processing Record 16 of Set 14 | arrah
# Processing Record 17 of Set 14 | miranorte
# City not found. Skipping...
# Processing Record 18 of Set 14 | fredericksburg
# Processing Record 19 of Set 14 | bjornevatn
# Processing Record 20 of Set 14 | salina
# Processing Record 21 of Set 14 | narasannapeta
# Processing Record 22 of Set 14 | manuk mangkaw
# Processing Record 23 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 24 of Set 14 | odweyne
# Processing Record 25 of Set 14 | pacific grove
# Processing Record 26 of Set 14 | luzhou
# Processing Record 27 of Set 14 | terney
# Processing Record 28 of Set 14 | bay saint louis
# Processing Record 29 of Set 14 | mackay
# Processing Record 30 of Set 14 | nishihara
# Processing Record 31 of Set 14 | isangel
# Processing Record 32 of Set 14 | awbari
# Processing Record 33 of Set 14 | clyde river
# Processing Record 34 of Set 14 | listvyanskiy
# Processing Record 35 of Set 14 | oyama
# Processing Record 36 of Set 14 | snasa
# Processing Record 37 of Set 14 | halifax
# Processing Record 38 of Set 14 | roebourne
# Processing Record 39 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 40 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 41 of Set 14 | buala
# Processing Record 42 of Set 14 | karratha
# Processing Record 43 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 44 of Set 14 | borger
# Processing Record 45 of Set 14 | wilmington
# Processing Record 46 of Set 14 | orange cove
# Processing Record 47 of Set 14 | reyes
# Processing Record 48 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 14 | yumen
# Processing Record 50 of Set 14 | moranbah
# Processing Record 1 of Set 15 | linxia
# Processing Record 2 of Set 15 | sadiqabad
# Processing Record 3 of Set 15 | onega
# Processing Record 4 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 5 of Set 15 | tanushimaru
# Processing Record 6 of Set 15 | shaunavon
# Processing Record 7 of Set 15 | gwanda
# Processing Record 8 of Set 15 | cidreira
# Processing Record 9 of Set 15 | bestobe
# Processing Record 10 of Set 15 | pampa
# Processing Record 11 of Set 15 | baykit
# Processing Record 12 of Set 15 | gamba
# Processing Record 13 of Set 15 | palora
# Processing Record 14 of Set 15 | kayerkan
# Processing Record 15 of Set 15 | praya
# Processing Record 16 of Set 15 | malakal
# Processing Record 17 of Set 15 | antalaha
# Processing Record 18 of Set 15 | port keats
# Processing Record 19 of Set 15 | araguacu
# Processing Record 20 of Set 15 | rivadavia
# Processing Record 21 of Set 15 | livadiya
# Processing Record 22 of Set 15 | morong
# Processing Record 23 of Set 15 | carutapera
# Processing Record 24 of Set 15 | mascote
# Processing Record 25 of Set 15 | hami
# Processing Record 26 of Set 15 | genhe
# Processing Record 27 of Set 15 | petrokamenskoye
# Processing Record 28 of Set 15 | lima
# Processing Record 29 of Set 15 | kudahuvadhoo
# Processing Record 30 of Set 15 | kulhudhuffushi
# Processing Record 31 of Set 15 | yilan
# Processing Record 32 of Set 15 | oriximina
# Processing Record 33 of Set 15 | albury
# Processing Record 34 of Set 15 | mastic beach
# Processing Record 35 of Set 15 | ciras
# City not found. Skipping...
# Processing Record 36 of Set 15 | nantucket
# Processing Record 37 of Set 15 | doha
# Processing Record 38 of Set 15 | hellvik
# Processing Record 39 of Set 15 | awallan
# Processing Record 40 of Set 15 | kristianstad
# Processing Record 41 of Set 15 | plouzane
# Processing Record 42 of Set 15 | presidencia roque saenz pena
# Processing Record 43 of Set 15 | marystown
# Processing Record 44 of Set 15 | ugoofaaru
# Processing Record 45 of Set 15 | vestmannaeyjar
# Processing Record 46 of Set 15 | phayao
# Processing Record 47 of Set 15 | chelmza
# Processing Record 48 of Set 15 | moyo
# Processing Record 49 of Set 15 | itaporanga
# Processing Record 50 of Set 15 | pafos
# Processing Record 1 of Set 16 | najran
# Processing Record 2 of Set 16 | marsa matruh
# Processing Record 3 of Set 16 | cruzeiro
# Processing Record 4 of Set 16 | kuytun
# Processing Record 5 of Set 16 | bam
# Processing Record 6 of Set 16 | oksbol
# Processing Record 7 of Set 16 | gardez
# Processing Record 8 of Set 16 | villa carlos paz
# Processing Record 9 of Set 16 | puerto montt
# Processing Record 10 of Set 16 | makung
# City not found. Skipping...
# Processing Record 11 of Set 16 | kerema
# Processing Record 12 of Set 16 | rudbar
# Processing Record 13 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 16 | mount isa
# Processing Record 15 of Set 16 | punta alta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 701

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Yellowknife      CA  62.4560 -114.3525     42.42        68          20
# 1    Saint-Paul      RE -21.0096   55.2707     77.09        67          13
# 2         Bluff      NZ -46.6000  168.3333     52.81        79         100
# 3        Albany      US  42.6001  -73.9662     62.53        95         100
# 4          Fare      PF -16.7000 -151.0167     78.57        73           9
# 5  Port Augusta      AU -32.5000  137.7667     70.70        25          30
# 6       Salalah      OM  17.0151   54.0924     80.69        89          75
# 7        Juneau      US  58.3019 -134.4197     41.22        96          90
# 8    Nanortalik      GL  60.1432  -45.2371     37.98        85           1
# 9      Thompson      CA  55.7435  -97.8558     44.76        87           1
#
#    Wind Speed Current Description
# 0        4.61          few clouds
# 1        4.07          few clouds
# 2       25.46     overcast clouds
# 3        1.95       moderate rain
# 4       10.33           clear sky
# 5       21.50    scattered clouds
# 6        5.75       broken clouds
# 7       10.36          light snow
# 8        2.75           clear sky
# 9        0.00               smoke

# %%
city_data_df.to_csv("weather_database/weatherpy_database.csv", index_label='City_ID')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/zs/4ywpf25d7p3_tb7s7lx7ck640000gn/T/ipykernel_6950/478947592.py in <module>
#       1 output_data_file = "weather_database/weatherpy_database.csv"
# ----> 2 city_data_df.to_csv(output_data_file, index_label='City_ID')
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/pandas/io/formats/csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'weather_database/weatherpy_database.csv'
